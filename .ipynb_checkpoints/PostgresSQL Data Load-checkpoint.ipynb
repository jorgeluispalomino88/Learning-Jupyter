# %% [markdown]
# First install the libraries
# * pip install ipython-sql
# * pip install sqlalchemy
# * pip install psycopg2

# %% [markdown]
# Load the ipython-sql extension

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Connect to the database

# %%
from sqlalchemy import create_engine
import pandas as pd

# %sql postgresql://postgres:admin@localhost/CIM

# %%
engine = create_engine('postgresql://postgres:admin@localhost/CIM')

# %% [markdown]
# Making SQL queries

# %%
# %%sql
# SELECT * FROM "rip"."registro_inclusion_pacientes_curated" LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/CIM
# 5 rows affected.
# [(datetime.datetime(2022, 1, 24, 10, 10, 24), datetime.datetime(2022, 1, 24, 10, 10, 24), 16982, 'IIC RD-EC181 Raco vs Nimo en CPCNP FIII', 'RDR', '05', datetime.date(2022, 1, 21), 'VAXIRA', 'VAXIRA', None, 'Hospital Celestino Hernández Robau', None, 'Villa Clara', None, None, 'Daymys Estevez', 'Daymys Estevez', None, None, None, 'Abierto', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'RDR - 05'),
# ...

# %% [markdown]
# Loading data into a pandas dataframe

# %%
df = pd.read_sql('SELECT * FROM "rip"."registro_inclusion_pacientes_curated" LIMIT 5',engine)

# %%
df.head()
# Out:
#              modified             created     id  \
# 0 2022-01-24 10:10:24 2022-01-24 10:10:24  16982
# 1 2022-01-24 10:10:24 2022-01-24 10:10:24  16982
# 2 2022-01-17 13:24:10 2022-01-17 13:24:10  16974
# 3 2022-01-17 10:28:49 2022-01-17 10:28:49  16966
# 4 2022-01-17 10:31:17 2022-01-17 10:31:17  16967
#
#                                     ensayo iniciales no. inclusión  \
# 0  IIC RD-EC181 Raco vs Nimo en CPCNP FIII       RDR            05
# 1  IIC RD-EC181 Raco vs Nimo en CPCNP FIII       RDR            05
# 2                              Compasional       MTR            NP
# 3                              Compasional       ADS            NP
# 4                              Compasional      URDT            NP
#
#   fecha. inclusión  producto tratamiento tipo de tumor  ...  \
# 0       2022-01-21    VAXIRA      VAXIRA          None  ...
# 1       2022-01-21   CIMAHER      VAXIRA          None  ...
# 2       2022-01-17  NEUROEPO        None          None  ...
# ...
